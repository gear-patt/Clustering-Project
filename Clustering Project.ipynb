# %%
import os
import pandas as pd
os.chdir('data')
data = pd.read_csv('Human_Activity_Recognition_Using_Smartphones_Data.csv')
data.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10299 entries, 0 to 10298
# Columns: 562 entries, tBodyAcc-mean()-X to Activity
# dtypes: float64(561), object(1)
# memory usage: 44.2+ MB

# %%
data.shape
# Out:
# (10299, 562)

# %%
data.Activity.value_counts()
# Out:
# LAYING                1944
# STANDING              1906
# SITTING               1777
# WALKING               1722
# WALKING_UPSTAIRS      1544
# WALKING_DOWNSTAIRS    1406
# Name: Activity, dtype: int64

# %%
original_data = data.copy()

# %%
data = data.drop('Activity', axis=1)
data.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
# ...

# %%
from sklearn.preprocessing import StandardScaler
s = StandardScaler()
data = s.fit_transform(data)

# %%
data
# Out:
# array([[ 2.10533854e-01, -6.87026385e-02, -4.52194533e-01, ...,
#         -6.74432366e-01,  3.82007658e-01, -1.61505480e-02],
#        [ 6.02084832e-02,  3.59023537e-02, -2.75221885e-01, ...,
#         -6.81359801e-01,  3.83147865e-01, -1.20627169e-04],
#        [ 7.84597052e-02, -4.64269585e-02, -8.55480582e-02, ...,
#         -6.89470939e-01,  3.84288531e-01,  1.92144041e-02],
#        ...,
#        [ 1.11821625e+00,  1.28805864e+00, -1.29414692e-01, ...,
#         -3.10750224e-01,  6.91509049e-01,  8.75719123e-01],
#        [-5.43492722e-01,  9.75327452e-01,  2.34319837e-01, ...,
#         -3.19283719e-01,  6.59762215e-01,  8.99444350e-01],
#        [-1.78515253e+00, -1.86663622e-02, -5.29759691e-01, ...,
#         -3.19991245e-01,  6.56994458e-01,  9.01454465e-01]])

# %%
from sklearn.decomposition import PCA
import numpy as np
pca_list = list()
feature_weight_list = list()

# Fit a range of PCA models

for n in [25, 50, 100, 200, 300, 400, 500]:
    
    # Create and fit the model
    PCAmod = PCA(n_components=n)
    PCAmod.fit(data)
    
    # Store the model and variance
    pca_list.append(pd.Series({'n':n, 'model':PCAmod,
                               'var': PCAmod.explained_variance_ratio_.sum()}))
    
    
pca_df = pd.concat(pca_list, axis=1).T.set_index('n')
pca_df
# Out:
#                      model       var
# n
# 25    PCA(n_components=25)  0.792437
# 50    PCA(n_components=50)  0.870901
# 100  PCA(n_components=100)  0.946318
# 200  PCA(n_components=200)  0.993228
# 300  PCA(n_components=300)  0.999025
# 400  PCA(n_components=400)  0.999971
# 500  PCA(n_components=500)       1.0

# %% [markdown]
# You can see that using PCA reducing the number of features from 561 features to 200 or 100 doesn't change the variance much. So, we can choose to use just 100 features to avoid curse of dimensionality.

# %%
data.shape
# Out:
# (10299, 561)

# %%
pca = PCA(n_components=100)
pca.fit(data)
data = pca.transform(data)
data
# Out:
# array([[-16.38097982,   1.99508307,   3.41569028, ...,  -1.20870374,
#           2.92838983,   0.40257999],
#        [-15.58217328,   1.18259368,  -0.32120673, ...,   0.18218697,
#           0.67887152,  -0.37513822],
#        [-15.42398918,   2.24316643,  -1.23778356, ...,  -0.86889159,
#          -0.97932253,   0.68880303],
#        ...,
#        [ 11.84685312,  -3.43356502,   2.18801928, ...,  -0.05642913,
#           0.27269065,  -0.63053278],
#        [  8.20668637,  -4.38648876,   1.31871956, ...,  -0.50100762,
#          -0.61089776,  -0.491033  ],
#        [  9.31117251,  -3.98616133,   1.93301749, ...,  -1.65574968,
#          -0.25428148,  -0.11642031]])

# %%
data.shape
# Out:
# (10299, 100)

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
inertia = []
list_num_clusters = list(range(1,11))
for num_clusters in list_num_clusters:
    km = KMeans(n_clusters=num_clusters)
    km.fit(data)
    inertia.append(km.inertia_)
    
plt.plot(list_num_clusters,inertia)
plt.scatter(list_num_clusters,inertia)
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia');

# %% [markdown]
# Since number of clusters=2 is the elbow point, we choose n_clusters=2.

# %%
km = KMeans(n_clusters=2)
km = km.fit(data)
km1 = km.predict(data)
km1
# Out:
# array([0, 0, 0, ..., 1, 1, 1], dtype=int32)

# %%
km = KMeans(n_clusters=6)
km = km.fit(data)
km2 = km.predict(data)
km2
# Out:
# array([1, 1, 1, ..., 0, 0, 0], dtype=int32)

# %%
original_data['km1'] = km1
original_data
# Out:
#        tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0               0.288585          -0.020294          -0.132905
# 1               0.278419          -0.016411          -0.123520
# 2               0.279653          -0.019467          -0.113462
# 3               0.279174          -0.026201          -0.123283
# 4               0.276629          -0.016570          -0.115362
# ...                  ...                ...                ...
# 10294           0.310155          -0.053391          -0.099109
# 10295           0.363385          -0.039214          -0.105915
# 10296           0.349966           0.030077          -0.115788
# 10297           0.237594           0.018467          -0.096499
# 10298           0.153627          -0.018437          -0.137018
#
#        tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 0             -0.995279         -0.983111         -0.913526         -0.995112
# ...

# %%
(original_data[['Activity', 'km1']]
 .groupby(['Activity','km1'])
 .size()
 .to_frame()
 .rename(columns={0:'number'}))
# Out:
#                         number
# Activity           km1
# LAYING             0      1932
#                    1        12
# SITTING            0      1774
#                    1         3
# STANDING           0      1906
# WALKING            1      1722
# WALKING_DOWNSTAIRS 1      1406
# WALKING_UPSTAIRS   0         8
#                    1      1536

# %%
original_data['km2'] = km2
(original_data[['Activity', 'km2']]
 .groupby(['Activity','km2'])
 .size()
 .to_frame()
 .rename(columns={0:'number'}))
# Out:
#                         number
# Activity           km2
# LAYING             0         5
#                    1        53
#                    2       330
#                    5      1556
# SITTING            0         1
#                    1      1234
#                    2       451
#                    5        91
# STANDING           1      1340
#                    2       566
# WALKING            0       897
#                    3       741
#                    4        84
# WALKING_DOWNSTAIRS 0       309
#                    3       883
#                    4       214
# WALKING_UPSTAIRS   0      1236
#                    2         2
#                    3       297
#                    4         9

# %% [markdown]
# You can see that the model segment the data into 2 groups, which makes sense because if the activity is given, the data is cleary seperated into moving and not moving.

# %%
from sklearn.cluster import AgglomerativeClustering
ag = AgglomerativeClustering(n_clusters=2, linkage='ward', compute_full_tree=True)
ag = ag.fit(data)
ag1 = ag.fit_predict(data)
ag1
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
original_data['ag1'] = ag1
(original_data[['Activity', 'ag1']]
 .groupby(['Activity','ag1'])
 .size()
 .to_frame()
 .rename(columns={0:'number'}))
# Out:
#                         number
# Activity           ag1
# LAYING             1      1944
# SITTING            1      1777
# STANDING           1      1906
# WALKING            0      1722
# WALKING_DOWNSTAIRS 0      1406
# WALKING_UPSTAIRS   0      1544

# %%
from sklearn.cluster import AgglomerativeClustering
ag = AgglomerativeClustering(n_clusters=6, linkage='ward', compute_full_tree=True)
ag = ag.fit(data)
ag2 = ag.fit_predict(data)
ag2
# Out:
# array([5, 1, 1, ..., 2, 2, 2])

# %%
original_data['ag2'] = ag2
(original_data[['Activity', 'ag2']]
 .groupby(['Activity','ag2'])
 .size()
 .to_frame()
 .rename(columns={0:'number'}))
# Out:
#                         number
# Activity           ag2
# LAYING             1        99
#                    4      1524
#                    5       321
# SITTING            1      1401
#                    4        12
#                    5       364
# STANDING           1      1800
#                    5       106
# WALKING            0       742
#                    2       954
#                    3        26
# WALKING_DOWNSTAIRS 0       847
#                    2       442
#                    3       117
# WALKING_UPSTAIRS   0       182
#                    2      1362

# %% [markdown]
# Using Logistic Regression to predict the acitivity with clustering and PCA techniques.

# %%
original_data
# Out:
#        tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0               0.288585          -0.020294          -0.132905
# 1               0.278419          -0.016411          -0.123520
# 2               0.279653          -0.019467          -0.113462
# 3               0.279174          -0.026201          -0.123283
# 4               0.276629          -0.016570          -0.115362
# ...                  ...                ...                ...
# 10294           0.310155          -0.053391          -0.099109
# 10295           0.363385          -0.039214          -0.105915
# 10296           0.349966           0.030077          -0.115788
# 10297           0.237594           0.018467          -0.096499
# 10298           0.153627          -0.018437          -0.137018
#
#        tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 0             -0.995279         -0.983111         -0.913526         -0.995112
# ...

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
activity = le.fit_transform(original_data.Activity)
activity
# Out:
# array([2, 2, 2, ..., 5, 5, 5])

# %%
list(le.classes_)
# Out:
# ['LAYING',
#  'SITTING',
#  'STANDING',
#  'WALKING',
#  'WALKING_DOWNSTAIRS',
#  'WALKING_UPSTAIRS']

# %%
original_data.Activity=activity
original_data
# Out:
#        tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0               0.288585          -0.020294          -0.132905
# 1               0.278419          -0.016411          -0.123520
# 2               0.279653          -0.019467          -0.113462
# 3               0.279174          -0.026201          -0.123283
# 4               0.276629          -0.016570          -0.115362
# ...                  ...                ...                ...
# 10294           0.310155          -0.053391          -0.099109
# 10295           0.363385          -0.039214          -0.105915
# 10296           0.349966           0.030077          -0.115788
# 10297           0.237594           0.018467          -0.096499
# 10298           0.153627          -0.018437          -0.137018
#
#        tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 0             -0.995279         -0.983111         -0.913526         -0.995112
# ...

# %%
x_with_agglo = original_data.drop(['Activity', 'km1', 'km2', 'ag2'], axis=1)
x_without_agglo = x_with_agglo.drop('ag1', axis=1)
y = original_data['Activity']

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import classification_report
s = StratifiedShuffleSplit(n_splits=1, random_state=0)

def train_models(x,y):
    train_idx, test_idx = next(s.split(x,y))
    x_train = x.iloc[train_idx,:]
    y_train = y.iloc[train_idx]
    x_test = x.iloc[test_idx,:]
    y_test = y.iloc[test_idx]
    lr = LogisticRegression(solver='liblinear').fit(x_train, y_train)
    y_predict = lr.predict(x_test)
    return classification_report(y_test, y_predict)

# %%
x_with_agglo
# Out:
#        tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0               0.288585          -0.020294          -0.132905
# 1               0.278419          -0.016411          -0.123520
# 2               0.279653          -0.019467          -0.113462
# 3               0.279174          -0.026201          -0.123283
# 4               0.276629          -0.016570          -0.115362
# ...                  ...                ...                ...
# 10294           0.310155          -0.053391          -0.099109
# 10295           0.363385          -0.039214          -0.105915
# 10296           0.349966           0.030077          -0.115788
# 10297           0.237594           0.018467          -0.096499
# 10298           0.153627          -0.018437          -0.137018
#
#        tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 0             -0.995279         -0.983111         -0.913526         -0.995112
# ...

# %%
x_without_agglo
# Out:
#        tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0               0.288585          -0.020294          -0.132905
# 1               0.278419          -0.016411          -0.123520
# 2               0.279653          -0.019467          -0.113462
# 3               0.279174          -0.026201          -0.123283
# 4               0.276629          -0.016570          -0.115362
# ...                  ...                ...                ...
# 10294           0.310155          -0.053391          -0.099109
# 10295           0.363385          -0.039214          -0.105915
# 10296           0.349966           0.030077          -0.115788
# 10297           0.237594           0.018467          -0.096499
# 10298           0.153627          -0.018437          -0.137018
#
#        tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 0             -0.995279         -0.983111         -0.913526         -0.995112
# ...

# %%
print(train_models(x_with_agglo, y))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       194
#            1       0.95      0.97      0.96       178
#            2       0.97      0.95      0.96       191
#            3       1.00      1.00      1.00       172
#            4       1.00      1.00      1.00       141
#            5       1.00      1.00      1.00       154
#
#     accuracy                           0.99      1030
#    macro avg       0.99      0.99      0.99      1030
# weighted avg       0.99      0.99      0.99      1030

# %%
print(train_models(x_without_agglo, y))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       194
#            1       0.95      0.97      0.96       178
#            2       0.97      0.95      0.96       191
#            3       1.00      1.00      1.00       172
#            4       1.00      1.00      1.00       141
#            5       1.00      1.00      1.00       154
#
#     accuracy                           0.99      1030
#    macro avg       0.99      0.99      0.99      1030
# weighted avg       0.99      0.99      0.99      1030
